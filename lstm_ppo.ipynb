# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import time
import numpy as np

# %%
#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 2
T_horizon     = 20

# %%
class Agent(nn.Module):
    def __init__(self,input_dim,output_dim):
        super(Agent,self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.data = []
        
        self.layer_1 = nn.Linear(input_dim,64)
        self.lstm_layer = nn.LSTM(64,32)
        self.actor = nn.Linear(32,output_dim)
        self.critic = nn.Linear(32,1)
        
        self.optimizer = optim.Adam(self.parameters(),lr = learning_rate)
        
    def get_action(self,x,hidden):
        x = F.relu(self.layer_1(x))
        x = x.view(-1,1,64)
        x, lstm_hidden = self.lstm_layer(x,hidden)
        
        x = self.actor(x)
        prob = F.softmax(x,dim = 2)
        return prob, lstm_hidden
    
    def get_value(self,x,hidden):
        x = F.relu(self.layer_1(x))
        x = x.view(-1,1,64)
        x, lstm_hidden = self.lstm_layer(x,hidden)
        v = self.critic(x)
        return v
    
    def put_data(self,x):
        self.data.append(x)
    
    def make_batch(self):
        state_lst, action_lst,reward_lst,next_state_lst,prob_lst,hidden_in_lst,\
        hidden_out_lst, done_lst = [],[],[],[],[],[],[],[]
        for transition in self.data:
            state,action,reward,next_state, prob,hidden_in,hidden_out,done = transition
            
            state_lst.append(state)
            action_lst.append([action])
            reward_lst.append([reward])
            next_state_lst.append(next_state)
            prob_lst.append([prob])
            hidden_in_lst.append(hidden_in)
            hidden_out_lst.append(hidden_out)
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
            
        state = torch.tensor(state_lst,dtype = torch.float)
        action = torch.tensor(action_lst)
        reward = torch.tensor(reward_lst)
        next_state = torch.tensor(next_state_lst,dtype = torch.float)
        prob = torch.tensor(prob_lst, dtype=torch.float)
        done_mask = torch.tensor(done_lst,dtype = torch.float)
        self.data = []
        return state,action,reward,next_state,prob,hidden_in_lst[0],hidden_out_lst[0],done_mask ##test

    def train(self):
        state,action,reward,next_state,prob,(hidden_in_1,hidden_in_2),\
        (hidden_out_1,hidden_out_2),done_mask = self.make_batch()
        
        first_hidden = (hidden_in_1.detach(),hidden_in_2.detach())
        second_hidden = (hidden_out_1.detach(),hidden_out_2.detach())
        for i in range(K_epoch):
            td_error = self.get_value(next_state,second_hidden).squeeze(1) ##test
            td_target = reward + gamma * td_error * done_mask
            td_value = self.get_value(state,first_hidden).squeeze(1)
            delta = td_target - td_value
            delta = delta.detach().numpy()
            
            advantage_lst = []
            advantage = 0.0
            for item in delta[::-1]:
                advantage = gamma * lmbda * advantage + item[0] ##test
                advantage_lst.append([advantage])
            advantage_lst.reverse()
            advantage = torch.tensor(advantage_lst, dtype = torch.float)
            
            action_prob, _ = self.get_action(state, first_hidden)
            action_selected = action_prob.squeeze(1).gather(1,action)
            ratio = torch.exp(torch.log(action_selected) - torch.log(prob))
            
            surr_1 = ratio * advantage
            surr_2 = torch.clamp(ratio, 1 - eps_clip, 1 + eps_clip)
            loss = -torch.min(surr_1,surr_2) + F.smooth_l1_loss(td_value,td_target.detach())
            self.optimizer.zero_grad()
            loss.mean().backward(retain_graph = True)
            self.optimizer.step()

# %%
import numpy as np
import os
from Building import Building
#from Agent import Agent
import time
#====================================================================================


#====================================================================================
#Building Setting
lift_num = 1
buliding_height = 5
max_people_in_floor = 8
max_people_in_elevator = 10

add_people_at_step = 25
add_people_prob = 0.8

#Create building with 4 elevators, height 10, max people 30 in each floor
building = Building(lift_num, buliding_height, max_people_in_floor,max_people_in_elevator)

#Agent controls each elevator
#agent = Agent(buliding_height, lift_num, 4)
#agent.reload(280)
#The goal is to bring down all the people in the building to the ground floor

epochs = 1000
max_steps = 100
global_step = 0
T_horizon = 20
reward_list = []
print_interval = 20

# %%
model = Agent((buliding_height)+ max_people_in_elevator + (lift_num *2),4)
print_interval = 20
ave_reward = 0

# %%
epochs = 100000

# %%
for epoch in range(epochs):
    building.empty_building()
    h_out = (torch.zeros([1, 1, 32], dtype=torch.float), torch.zeros([1, 1, 32], dtype=torch.float))
    while building.target == 0 :
        building.generate_people(add_people_prob)
    first_state = building.target
    state = building.get_state()
    done = False
    global_step = 0
    while not done:
        for t in range(T_horizon):
            h_in = h_out
            global_step += 1
            if (global_step % 25 == 0) & global_step > 0 :
                #building.generate_people(add_people_prob/2)
                pass
            action_prob, h_out = model.get_action(torch.from_numpy(np.array(state)).float(), h_in)
            action_prob = action_prob.view(-1)
            m = Categorical(action_prob)
            action = m.sample().item()
            building.perform_action([action])
            reward = building.get_reward() 
            
            next_state = building.get_state()
            finished = next_state.copy()
            del finished[-2:]
            if (sum(finished) == 0.0) :
                reward = 100. #* building.target
                done = True
            #print(sum(finished))
            #print('global_step : ',global_step,'state : ',state, 'action : ', action, 'reward : ',reward/float(first_state), 'done : ',done)
            #print('global_step : ',global_step,'state : ',state, 'action : ', action, 'reward : ',reward/10., 'done : ',done)
            #model.put_data((state, action, reward/float(first_state), next_state, action_prob[action].item(), done))
            #model.put_data((state, action, reward/10.0, next_state, action_prob[action].item(), done))
            model.put_data((state, action, reward/10.0, next_state, action_prob[action].item(), h_in, h_out, done))
            state = next_state
            
            if done or (global_step > 300):
                done = True
                break

        model.train()
    ave_reward += global_step 
    #print("Epoch: %d Step: %d Average Reward: %.4f"%(epoch, global_step, ave_reward/global_step))
    if epoch%print_interval==0 and epoch!=0:
        print("# of episode :{}, avg score : {:.1f}".format(epoch, ave_reward/print_interval))
        ave_reward = 0
    if (epoch % 1000 == 0 )& (epoch != 0):
        torch.save(model.state_dict(), './model_weights/recurrent_model_'+str(epoch))
    reward_list.append(global_step)
# Out:
# # of episode :20, avg score : 68.5
# # of episode :40, avg score : 42.0
# # of episode :60, avg score : 43.2
# # of episode :80, avg score : 37.6
# # of episode :100, avg score : 44.0
# # of episode :120, avg score : 41.2
# # of episode :140, avg score : 40.2
# # of episode :160, avg score : 35.2
# # of episode :180, avg score : 40.0
# # of episode :200, avg score : 36.6
# # of episode :220, avg score : 33.6
# # of episode :240, avg score : 41.1
# # of episode :260, avg score : 59.4
# # of episode :280, avg score : 43.2
# # of episode :300, avg score : 40.2
# # of episode :320, avg score : 38.5
# # of episode :340, avg score : 41.7
# # of episode :360, avg score : 44.5
# # of episode :380, avg score : 44.5
# # of episode :400, avg score : 43.0
# # of episode :420, avg score : 43.4
# # of episode :440, avg score : 44.8
# # of episode :460, avg score : 49.5
# # of episode :480, avg score : 38.1
# # of episode :500, avg score : 45.8
# # of episode :520, avg score : 42.2
# # of episode :540, avg score : 44.6
# # of episode :560, avg score : 39.9
# # of episode :580, avg score : 43.1
# # of episode :600, avg score : 41.0
# # of episode :620, avg score : 35.5
# # of episode :640, avg score : 39.0
# # of episode :660, avg score : 57.0
# # of episode :680, avg score : 43.8
# # of episode :700, avg score : 43.9
# # of episode :720, avg score : 52.8
# # of episode :740, avg score : 41.3
# # of episode :760, avg score : 42.3
# # of episode :780, avg score : 33.8
# # of episode :800, avg score : 37.4
# # of episode :820, avg score : 36.5
# # of episode :840, avg score : 41.6
# # of episode :860, avg score : 40.8
# # of episode :880, avg score : 41.2
# # of episode :900, avg score : 44.0
# # of episode :920, avg score : 42.1
# # of episode :940, avg score : 41.2
# # of episode :960, avg score : 37.0
# # of episode :980, avg score : 44.4
# # of episode :1000, avg score : 43.2
# # of episode :1020, avg score : 43.5
# # of episode :1040, avg score : 41.0
# # of episode :1060, avg score : 45.8
# # of episode :1080, avg score : 50.6
# # of episode :1100, avg score : 43.0
# # of episode :1120, avg score : 39.7
# # of episode :1140, avg score : 41.2
# # of episode :1160, avg score : 39.9
# # of episode :1180, avg score : 42.0
# # of episode :1200, avg score : 40.6
# # of episode :1220, avg score : 44.9
# # of episode :1240, avg score : 37.2
# # of episode :1260, avg score : 36.0
# # of episode :1280, avg score : 37.6
# # of episode :1300, avg score : 37.5
# # of episode :1320, avg score : 37.5
# # of episode :1340, avg score : 39.8
# # of episode :1360, avg score : 40.5
# # of episode :1380, avg score : 53.5
# # of episode :1400, avg score : 38.8
# # of episode :1420, avg score : 38.8
# # of episode :1440, avg score : 42.5
# # of episode :1460, avg score : 41.4
# # of episode :1480, avg score : 44.0
# # of episode :1500, avg score : 40.6
# # of episode :1520, avg score : 42.5
# # of episode :1540, avg score : 36.9
# # of episode :1560, avg score : 46.4
# # of episode :1580, avg score : 36.6
# # of episode :1600, avg score : 51.5
# # of episode :1620, avg score : 36.4
# # of episode :1640, avg score : 54.1
# # of episode :1660, avg score : 42.7
# # of episode :1680, avg score : 48.1
# # of episode :1700, avg score : 44.2
# # of episode :1720, avg score : 40.0
# # of episode :1740, avg score : 45.2
# # of episode :1760, avg score : 38.6
# # of episode :1780, avg score : 41.8
# # of episode :1800, avg score : 40.9
# # of episode :1820, avg score : 40.5
# # of episode :1840, avg score : 39.6
# # of episode :1860, avg score : 44.5
# # of episode :1880, avg score : 38.5
# # of episode :1900, avg score : 39.5
# # of episode :1920, avg score : 42.4
# # of episode :1940, avg score : 34.5
# # of episode :1960, avg score : 38.1
# # of episode :1980, avg score : 40.7
# # of episode :2000, avg score : 38.2
# # of episode :2020, avg score : 40.5
# # of episode :2040, avg score : 42.0
# # of episode :2060, avg score : 44.2
# # of episode :2080, avg score : 46.7
# # of episode :2100, avg score : 41.2
# # of episode :2120, avg score : 40.7
# # of episode :2140, avg score : 38.5
# # of episode :2160, avg score : 38.5
# # of episode :2180, avg score : 42.3
# # of episode :2200, avg score : 40.6
# # of episode :2220, avg score : 48.4
# # of episode :2240, avg score : 42.4
# # of episode :2260, avg score : 43.0
# # of episode :2280, avg score : 43.8
# # of episode :2300, avg score : 45.6
# # of episode :2320, avg score : 39.4
# # of episode :2340, avg score : 37.1
# # of episode :2360, avg score : 36.1
# # of episode :2380, avg score : 43.7
# # of episode :2400, avg score : 39.6
# # of episode :2420, avg score : 40.9
# # of episode :2440, avg score : 40.4
# # of episode :2460, avg score : 40.4
# # of episode :2480, avg score : 36.0
# # of episode :2500, avg score : 42.8
# # of episode :2520, avg score : 40.5
# # of episode :2540, avg score : 37.8
# # of episode :2560, avg score : 41.4
# # of episode :2580, avg score : 44.1
# # of episode :2600, avg score : 44.2
# # of episode :2620, avg score : 48.0
# # of episode :2640, avg score : 42.5
# # of episode :2660, avg score : 39.0
# # of episode :2680, avg score : 39.6
# # of episode :2700, avg score : 40.8
# # of episode :2720, avg score : 48.6
# # of episode :2740, avg score : 36.1
# # of episode :2760, avg score : 45.0
# # of episode :2780, avg score : 41.2
# # of episode :2800, avg score : 40.8
# # of episode :2820, avg score : 35.8
# # of episode :2840, avg score : 41.5
# # of episode :2860, avg score : 41.6
# # of episode :2880, avg score : 38.4
# # of episode :2900, avg score : 39.5
# # of episode :2920, avg score : 39.0
# # of episode :2940, avg score : 42.1
# # of episode :2960, avg score : 38.6
# # of episode :2980, avg score : 47.3
# # of episode :3000, avg score : 41.7
# # of episode :3020, avg score : 41.4
# # of episode :3040, avg score : 36.6
# # of episode :3060, avg score : 39.0
# # of episode :3080, avg score : 38.6
# # of episode :3100, avg score : 37.0
# # of episode :3120, avg score : 37.2
# # of episode :3140, avg score : 50.7
# # of episode :3160, avg score : 44.8
# # of episode :3180, avg score : 35.5
# # of episode :3200, avg score : 43.4
# # of episode :3220, avg score : 40.5
# # of episode :3240, avg score : 36.5
# # of episode :3260, avg score : 37.9
# # of episode :3280, avg score : 42.5
# # of episode :3300, avg score : 38.4
# # of episode :3320, avg score : 40.6
# # of episode :3340, avg score : 36.7
# # of episode :3360, avg score : 40.1
# # of episode :3380, avg score : 44.1
# # of episode :3400, avg score : 36.2
# # of episode :3420, avg score : 40.7
# # of episode :3440, avg score : 36.6
# # of episode :3460, avg score : 54.2
# # of episode :3480, avg score : 39.0
# # of episode :3500, avg score : 36.6
# # of episode :3520, avg score : 43.2
# # of episode :3540, avg score : 39.8
# # of episode :3560, avg score : 36.0
# # of episode :3580, avg score : 51.2
# # of episode :3600, avg score : 37.2
# # of episode :3620, avg score : 37.1
# # of episode :3640, avg score : 40.8
# # of episode :3660, avg score : 34.8
# # of episode :3680, avg score : 42.8
# # of episode :3700, avg score : 41.5
# # of episode :3720, avg score : 38.9
# # of episode :3740, avg score : 38.7
# # of episode :3760, avg score : 43.6
# # of episode :3780, avg score : 42.6
# # of episode :3800, avg score : 36.9
# # of episode :3820, avg score : 37.6
# # of episode :3840, avg score : 37.9
# # of episode :3860, avg score : 46.1
# # of episode :3880, avg score : 48.0
# # of episode :3900, avg score : 36.9
# # of episode :3920, avg score : 40.9
# # of episode :3940, avg score : 44.3
# # of episode :3960, avg score : 37.8
# # of episode :3980, avg score : 45.3
# # of episode :4000, avg score : 49.0
# # of episode :4020, avg score : 37.2
# # of episode :4040, avg score : 39.0
# # of episode :4060, avg score : 40.9
# # of episode :4080, avg score : 40.4
# # of episode :4100, avg score : 35.4
# # of episode :4120, avg score : 36.5
# # of episode :4140, avg score : 35.0
# # of episode :4160, avg score : 41.9
# # of episode :4180, avg score : 42.8
# # of episode :4200, avg score : 41.0
# # of episode :4220, avg score : 48.2
# # of episode :4240, avg score : 36.8
# # of episode :4260, avg score : 39.5
# # of episode :4280, avg score : 37.8
# # of episode :4300, avg score : 37.6
# # of episode :4320, avg score : 36.8
# # of episode :4340, avg score : 38.5
# # of episode :4360, avg score : 40.8
# # of episode :4380, avg score : 40.5
# # of episode :4400, avg score : 44.1
# # of episode :4420, avg score : 38.2
# # of episode :4440, avg score : 36.4
# # of episode :4460, avg score : 40.8
# # of episode :4480, avg score : 33.3
# # of episode :4500, avg score : 46.6
# # of episode :4520, avg score : 38.6
# # of episode :4540, avg score : 40.8
# # of episode :4560, avg score : 40.9
# # of episode :4580, avg score : 36.0
# # of episode :4600, avg score : 34.9
# # of episode :4620, avg score : 45.9
# # of episode :4640, avg score : 34.3
# # of episode :4660, avg score : 41.4
# # of episode :4680, avg score : 40.7
# # of episode :4700, avg score : 44.2
# # of episode :4720, avg score : 36.3
# # of episode :4740, avg score : 36.6
# # of episode :4760, avg score : 41.2
# # of episode :4780, avg score : 40.9
# # of episode :4800, avg score : 40.2
# # of episode :4820, avg score : 42.9
# # of episode :4840, avg score : 38.2
# # of episode :4860, avg score : 39.9
# # of episode :4880, avg score : 41.5
# # of episode :4900, avg score : 40.5
# # of episode :4920, avg score : 43.4
# # of episode :4940, avg score : 48.0
# # of episode :4960, avg score : 42.4
# # of episode :4980, avg score : 39.0
# # of episode :5000, avg score : 40.7
# # of episode :5020, avg score : 37.3
# # of episode :5040, avg score : 40.9
# # of episode :5060, avg score : 40.0
# # of episode :5080, avg score : 45.1
# # of episode :5100, avg score : 43.5
# # of episode :5120, avg score : 43.2
# # of episode :5140, avg score : 39.8
# # of episode :5160, avg score : 42.8
# # of episode :5180, avg score : 39.0
# # of episode :5200, avg score : 42.0
# # of episode :5220, avg score : 36.2
# # of episode :5240, avg score : 35.0
# # of episode :5260, avg score : 36.0
# # of episode :5280, avg score : 55.4
# # of episode :5300, avg score : 40.1
# # of episode :5320, avg score : 38.2
# # of episode :5340, avg score : 32.4
# # of episode :5360, avg score : 45.7
# # of episode :5380, avg score : 43.4
# # of episode :5400, avg score : 40.0
# # of episode :5420, avg score : 35.3
# # of episode :5440, avg score : 36.0
# # of episode :5460, avg score : 40.3
# # of episode :5480, avg score : 36.0
# # of episode :5500, avg score : 41.2
# # of episode :5520, avg score : 39.6
# # of episode :5540, avg score : 42.8
# # of episode :5560, avg score : 35.5
# # of episode :5580, avg score : 39.5
# # of episode :5600, avg score : 40.1
# # of episode :5620, avg score : 40.3
# # of episode :5640, avg score : 38.1
# # of episode :5660, avg score : 39.7
# # of episode :5680, avg score : 40.8
# # of episode :5700, avg score : 42.8
# # of episode :5720, avg score : 41.0
# # of episode :5740, avg score : 35.6
# # of episode :5760, avg score : 36.5
# # of episode :5780, avg score : 36.3
# # of episode :5800, avg score : 86.7
# # of episode :5820, avg score : 36.9
# # of episode :5840, avg score : 40.2
# # of episode :5860, avg score : 39.0
# # of episode :5880, avg score : 37.8
# # of episode :5900, avg score : 33.2
# # of episode :5920, avg score : 39.0
# # of episode :5940, avg score : 36.4
# # of episode :5960, avg score : 42.2
# # of episode :5980, avg score : 44.2
# # of episode :6000, avg score : 39.2
# # of episode :6020, avg score : 34.4
# # of episode :6040, avg score : 47.2
# # of episode :6060, avg score : 38.5
# # of episode :6080, avg score : 34.5
# # of episode :6100, avg score : 40.6
# # of episode :6120, avg score : 38.8
# # of episode :6140, avg score : 40.1
# # of episode :6160, avg score : 37.0
# # of episode :6180, avg score : 38.2
# # of episode :6200, avg score : 37.9
# # of episode :6220, avg score : 35.1
# # of episode :6240, avg score : 44.5
# # of episode :6260, avg score : 41.3
# # of episode :6280, avg score : 42.0
# # of episode :6300, avg score : 43.5
# # of episode :6320, avg score : 49.6
# # of episode :6340, avg score : 53.6
# # of episode :6360, avg score : 40.1
# # of episode :6380, avg score : 37.0
# # of episode :6400, avg score : 56.2
# # of episode :6420, avg score : 43.7
# # of episode :6440, avg score : 38.9
# # of episode :6460, avg score : 33.5
# # of episode :6480, avg score : 39.0
# # of episode :6500, avg score : 34.5
# # of episode :6520, avg score : 43.9
# # of episode :6540, avg score : 39.8
# # of episode :6560, avg score : 36.3
# # of episode :6580, avg score : 37.5
# # of episode :6600, avg score : 41.6
# # of episode :6620, avg score : 33.0
# # of episode :6640, avg score : 50.4
# # of episode :6660, avg score : 36.1
# # of episode :6680, avg score : 37.5
# # of episode :6700, avg score : 38.0
# # of episode :6720, avg score : 39.0
# # of episode :6740, avg score : 35.3
# # of episode :6760, avg score : 35.2
# # of episode :6780, avg score : 35.2
# # of episode :6800, avg score : 38.2
# # of episode :6820, avg score : 38.5
# # of episode :6840, avg score : 39.0
# # of episode :6860, avg score : 37.8
# # of episode :6880, avg score : 36.8
# # of episode :6900, avg score : 37.9
# # of episode :6920, avg score : 37.6
# # of episode :6940, avg score : 36.5
# # of episode :6960, avg score : 41.4
# # of episode :6980, avg score : 35.2
# # of episode :7000, avg score : 37.6
# # of episode :7020, avg score : 44.8
# # of episode :7040, avg score : 39.0
# # of episode :7060, avg score : 37.6
# # of episode :7080, avg score : 50.9
# # of episode :7100, avg score : 34.4
# # of episode :7120, avg score : 33.3
# # of episode :7140, avg score : 42.4
# # of episode :7160, avg score : 35.9
# # of episode :7180, avg score : 32.9
# # of episode :7200, avg score : 35.5
# # of episode :7220, avg score : 38.1
# # of episode :7240, avg score : 35.0
# # of episode :7260, avg score : 41.6
# # of episode :7280, avg score : 40.9
# # of episode :7300, avg score : 37.8
# # of episode :7320, avg score : 39.2
# # of episode :7340, avg score : 45.1
# # of episode :7360, avg score : 37.5
# # of episode :7380, avg score : 42.8
# # of episode :7400, avg score : 37.0
# # of episode :7420, avg score : 37.1
# # of episode :7440, avg score : 36.1
# # of episode :7460, avg score : 42.2
# # of episode :7480, avg score : 40.0
# # of episode :7500, avg score : 45.8
# # of episode :7520, avg score : 46.0
# # of episode :7540, avg score : 33.9
# # of episode :7560, avg score : 53.1
# # of episode :7580, avg score : 35.5
# # of episode :7600, avg score : 42.5
# # of episode :7620, avg score : 37.1
# # of episode :7640, avg score : 31.2
# # of episode :7660, avg score : 46.0
# # of episode :7680, avg score : 39.4
# # of episode :7700, avg score : 38.2
# # of episode :7720, avg score : 42.9
# # of episode :7740, avg score : 38.0
# # of episode :7760, avg score : 43.5
# # of episode :7780, avg score : 36.9
# # of episode :7800, avg score : 43.0
# # of episode :7820, avg score : 43.5
# # of episode :7840, avg score : 35.4
# # of episode :7860, avg score : 36.5
# # of episode :7880, avg score : 37.0
# # of episode :7900, avg score : 36.1
# # of episode :7920, avg score : 37.5
# # of episode :7940, avg score : 36.5
# # of episode :7960, avg score : 38.0
# # of episode :7980, avg score : 35.0
# # of episode :8000, avg score : 40.5
# # of episode :8020, avg score : 32.4
# # of episode :8040, avg score : 40.4
# # of episode :8060, avg score : 43.0
# # of episode :8080, avg score : 40.1
# # of episode :8100, avg score : 36.9
# # of episode :8120, avg score : 38.8
# # of episode :8140, avg score : 39.0
# # of episode :8160, avg score : 36.2
# # of episode :8180, avg score : 42.2
# # of episode :8200, avg score : 42.4
# # of episode :8220, avg score : 42.2
# # of episode :8240, avg score : 41.6
# # of episode :8260, avg score : 36.9
# # of episode :8280, avg score : 37.9
# # of episode :8300, avg score : 35.4
# # of episode :8320, avg score : 50.8
# # of episode :8340, avg score : 36.7
# # of episode :8360, avg score : 39.1
# # of episode :8380, avg score : 36.8
# # of episode :8400, avg score : 35.6
# # of episode :8420, avg score : 40.1
# # of episode :8440, avg score : 31.4
# # of episode :8460, avg score : 43.0
# # of episode :8480, avg score : 39.5
# # of episode :8500, avg score : 34.5
# # of episode :8520, avg score : 40.5
# # of episode :8540, avg score : 30.0
# # of episode :8560, avg score : 39.2
# # of episode :8580, avg score : 37.9
# # of episode :8600, avg score : 39.5
# # of episode :8620, avg score : 33.8
# # of episode :8640, avg score : 36.0
# # of episode :8660, avg score : 37.1
# # of episode :8680, avg score : 37.0
# # of episode :8700, avg score : 39.2
# # of episode :8720, avg score : 38.5
# # of episode :8740, avg score : 37.3
# # of episode :8760, avg score : 32.3
# # of episode :8780, avg score : 39.5
# # of episode :8800, avg score : 33.0
# # of episode :8820, avg score : 37.0
# # of episode :8840, avg score : 41.2
# # of episode :8860, avg score : 38.1
# # of episode :8880, avg score : 41.9
# # of episode :8900, avg score : 37.4
# # of episode :8920, avg score : 34.8
# # of episode :8940, avg score : 39.1
# # of episode :8960, avg score : 38.2
# # of episode :8980, avg score : 42.0
# # of episode :9000, avg score : 37.2
# # of episode :9020, avg score : 37.3
# # of episode :9040, avg score : 38.3
# # of episode :9060, avg score : 39.6
# # of episode :9080, avg score : 32.6
# # of episode :9100, avg score : 34.4
# # of episode :9120, avg score : 41.2
# # of episode :9140, avg score : 44.5
# # of episode :9160, avg score : 38.5
# # of episode :9180, avg score : 33.3
# # of episode :9200, avg score : 38.8
# # of episode :9220, avg score : 41.7
# # of episode :9240, avg score : 40.1
# # of episode :9260, avg score : 35.5
# # of episode :9280, avg score : 41.9
# # of episode :9300, avg score : 38.0
# # of episode :9320, avg score : 34.4
# # of episode :9340, avg score : 35.5
# # of episode :9360, avg score : 38.5
# # of episode :9380, avg score : 38.0
# # of episode :9400, avg score : 37.0
# # of episode :9420, avg score : 39.0
# # of episode :9440, avg score : 38.8
# # of episode :9460, avg score : 32.7
# # of episode :9480, avg score : 36.1
# # of episode :9500, avg score : 37.8
# # of episode :9520, avg score : 34.9
# # of episode :9540, avg score : 36.0
# # of episode :9560, avg score : 38.0
# # of episode :9580, avg score : 31.6
# # of episode :9600, avg score : 31.3
# # of episode :9620, avg score : 36.0
# # of episode :9640, avg score : 38.7
# # of episode :9660, avg score : 39.6
# # of episode :9680, avg score : 39.2
# # of episode :9700, avg score : 43.8
# # of episode :9720, avg score : 44.3
# # of episode :9740, avg score : 37.4
# # of episode :9760, avg score : 35.1
# # of episode :9780, avg score : 51.4
# # of episode :9800, avg score : 37.6
# # of episode :9820, avg score : 39.1
# # of episode :9840, avg score : 38.9
# # of episode :9860, avg score : 42.0
# # of episode :9880, avg score : 35.8
# # of episode :9900, avg score : 34.5
# # of episode :9920, avg score : 41.7
# # of episode :9940, avg score : 32.2
# # of episode :9960, avg score : 36.5
# # of episode :9980, avg score : 31.9
# # of episode :10000, avg score : 36.9
# # of episode :10020, avg score : 38.2
# # of episode :10040, avg score : 41.6
# # of episode :10060, avg score : 38.0
# # of episode :10080, avg score : 40.1
# # of episode :10100, avg score : 50.9
# # of episode :10120, avg score : 37.0
# # of episode :10140, avg score : 38.4
# # of episode :10160, avg score : 39.9
# # of episode :10180, avg score : 41.0
# # of episode :10200, avg score : 33.7
# # of episode :10220, avg score : 35.0
# # of episode :10240, avg score : 35.7
# # of episode :10260, avg score : 37.5
# # of episode :10280, avg score : 35.0
# # of episode :10300, avg score : 35.5
# # of episode :10320, avg score : 40.5
# # of episode :10340, avg score : 35.2
# # of episode :10360, avg score : 38.5
# # of episode :10380, avg score : 41.2
# # of episode :10400, avg score : 34.8
# # of episode :10420, avg score : 31.6
# # of episode :10440, avg score : 30.6
# # of episode :10460, avg score : 36.3
# # of episode :10480, avg score : 35.0
# # of episode :10500, avg score : 39.1
# # of episode :10520, avg score : 35.1
# # of episode :10540, avg score : 32.1
# # of episode :10560, avg score : 37.2
# # of episode :10580, avg score : 35.2
# # of episode :10600, avg score : 37.4
# # of episode :10620, avg score : 39.9
# # of episode :10640, avg score : 39.2
# # of episode :10660, avg score : 35.0
# # of episode :10680, avg score : 37.4
# # of episode :10700, avg score : 34.9
# # of episode :10720, avg score : 36.0
# # of episode :10740, avg score : 33.8
# # of episode :10760, avg score : 34.6
# # of episode :10780, avg score : 36.6
# # of episode :10800, avg score : 49.8
# # of episode :10820, avg score : 37.6
# # of episode :10840, avg score : 37.6
# # of episode :10860, avg score : 33.1
# # of episode :10880, avg score : 39.0
# # of episode :10900, avg score : 36.9
# # of episode :10920, avg score : 39.5
# # of episode :10940, avg score : 40.4
# # of episode :10960, avg score : 41.4
# # of episode :10980, avg score : 37.0
# # of episode :11000, avg score : 35.1
# # of episode :11020, avg score : 40.2
# # of episode :11040, avg score : 36.5
# # of episode :11060, avg score : 38.1
# # of episode :11080, avg score : 35.3
# # of episode :11100, avg score : 41.5
# # of episode :11120, avg score : 39.2
# # of episode :11140, avg score : 45.5
# # of episode :11160, avg score : 33.4
# # of episode :11180, avg score : 29.9
# # of episode :11200, avg score : 35.6
# # of episode :11220, avg score : 38.1
# # of episode :11240, avg score : 38.5
# # of episode :11260, avg score : 35.4
# # of episode :11280, avg score : 34.1
# # of episode :11300, avg score : 39.7
# # of episode :11320, avg score : 39.1
# # of episode :11340, avg score : 42.0
# # of episode :11360, avg score : 36.0
# # of episode :11380, avg score : 39.0
# # of episode :11400, avg score : 36.5
# # of episode :11420, avg score : 34.2
# # of episode :11440, avg score : 34.8
# # of episode :11460, avg score : 42.5
# # of episode :11480, avg score : 39.5
# # of episode :11500, avg score : 40.4
# # of episode :11520, avg score : 38.2
# # of episode :11540, avg score : 42.9
# # of episode :11560, avg score : 44.2
# # of episode :11580, avg score : 35.1
# # of episode :11600, avg score : 36.5
# # of episode :11620, avg score : 30.9
# # of episode :11640, avg score : 34.5
# # of episode :11660, avg score : 33.6
# # of episode :11680, avg score : 32.5
# # of episode :11700, avg score : 35.8
# # of episode :11720, avg score : 31.4
# # of episode :11740, avg score : 39.3
# # of episode :11760, avg score : 44.5
# # of episode :11780, avg score : 39.4
# # of episode :11800, avg score : 38.5
# # of episode :11820, avg score : 43.1
# # of episode :11840, avg score : 32.6
# # of episode :11860, avg score : 37.8
# # of episode :11880, avg score : 33.2
# # of episode :11900, avg score : 36.0
# # of episode :11920, avg score : 39.0
# # of episode :11940, avg score : 38.0
# # of episode :11960, avg score : 33.5
# # of episode :11980, avg score : 36.6
# # of episode :12000, avg score : 42.5
# # of episode :12020, avg score : 34.2
# # of episode :12040, avg score : 30.6
# # of episode :12060, avg score : 37.2
# # of episode :12080, avg score : 41.1
# # of episode :12100, avg score : 37.0
# # of episode :12120, avg score : 33.5
# # of episode :12140, avg score : 32.8
# # of episode :12160, avg score : 31.3
# # of episode :12180, avg score : 36.0
# # of episode :12200, avg score : 46.2
# # of episode :12220, avg score : 38.6
# # of episode :12240, avg score : 34.1
# # of episode :12260, avg score : 37.6
# # of episode :12280, avg score : 32.3
# # of episode :12300, avg score : 32.2
# # of episode :12320, avg score : 32.5
# # of episode :12340, avg score : 34.8
# # of episode :12360, avg score : 38.5
# # of episode :12380, avg score : 34.8
# # of episode :12400, avg score : 33.5
# # of episode :12420, avg score : 38.0
# # of episode :12440, avg score : 33.1
# # of episode :12460, avg score : 37.5
# # of episode :12480, avg score : 38.5
# # of episode :12500, avg score : 33.0
# # of episode :12520, avg score : 32.2
# # of episode :12540, avg score : 43.9
# # of episode :12560, avg score : 34.2
# # of episode :12580, avg score : 33.2
# # of episode :12600, avg score : 32.6
# # of episode :12620, avg score : 38.9
# # of episode :12640, avg score : 38.2
# # of episode :12660, avg score : 39.5
# # of episode :12680, avg score : 36.8
# # of episode :12700, avg score : 36.9
# # of episode :12720, avg score : 39.0
# # of episode :12740, avg score : 41.2
# # of episode :12760, avg score : 35.0
# # of episode :12780, avg score : 37.1
# # of episode :12800, avg score : 36.0
# # of episode :12820, avg score : 39.6
# # of episode :12840, avg score : 40.2
# # of episode :12860, avg score : 41.8
# # of episode :12880, avg score : 35.8
# # of episode :12900, avg score : 38.5
# # of episode :12920, avg score : 35.1
# # of episode :12940, avg score : 35.0
# # of episode :12960, avg score : 36.0
# # of episode :12980, avg score : 43.4
# # of episode :13000, avg score : 35.0
# # of episode :13020, avg score : 35.2
# # of episode :13040, avg score : 37.6
# # of episode :13060, avg score : 34.9
# # of episode :13080, avg score : 36.6
# # of episode :13100, avg score : 40.1
# # of episode :13120, avg score : 33.2
# # of episode :13140, avg score : 36.5
# # of episode :13160, avg score : 36.0
# # of episode :13180, avg score : 33.7
# # of episode :13200, avg score : 34.5
# # of episode :13220, avg score : 38.4
# # of episode :13240, avg score : 37.3
# # of episode :13260, avg score : 31.8
# # of episode :13280, avg score : 34.2
# # of episode :13300, avg score : 37.2
# # of episode :13320, avg score : 37.5
# # of episode :13340, avg score : 34.6
# # of episode :13360, avg score : 35.1
# # of episode :13380, avg score : 37.7
# # of episode :13400, avg score : 35.4
# # of episode :13420, avg score : 33.5
# # of episode :13440, avg score : 37.0
# # of episode :13460, avg score : 31.1
# # of episode :13480, avg score : 30.6
# # of episode :13500, avg score : 41.9
# # of episode :13520, avg score : 31.2
# # of episode :13540, avg score : 48.6
# # of episode :13560, avg score : 34.4
# # of episode :13580, avg score : 35.0
# # of episode :13600, avg score : 35.3
# # of episode :13620, avg score : 28.5
# # of episode :13640, avg score : 33.5
# # of episode :13660, avg score : 33.2
# # of episode :13680, avg score : 39.0
# # of episode :13700, avg score : 30.8
# # of episode :13720, avg score : 30.4
# # of episode :13740, avg score : 27.2
# # of episode :13760, avg score : 36.6
# # of episode :13780, avg score : 38.6
# # of episode :13800, avg score : 50.5
# # of episode :13820, avg score : 31.2
# # of episode :13840, avg score : 32.4
# # of episode :13860, avg score : 32.0
# # of episode :13880, avg score : 33.9
# # of episode :13900, avg score : 35.5
# # of episode :13920, avg score : 32.8
# # of episode :13940, avg score : 35.0
# # of episode :13960, avg score : 31.8
# # of episode :13980, avg score : 34.0
# # of episode :14000, avg score : 33.8
# # of episode :14020, avg score : 31.9
# # of episode :14040, avg score : 29.4
# # of episode :14060, avg score : 29.9
# # of episode :14080, avg score : 32.5
# # of episode :14100, avg score : 34.7
# # of episode :14120, avg score : 31.4
# # of episode :14140, avg score : 34.6
# # of episode :14160, avg score : 32.8
# # of episode :14180, avg score : 29.1
# # of episode :14200, avg score : 36.4
# # of episode :14220, avg score : 31.7
# # of episode :14240, avg score : 36.5
# # of episode :14260, avg score : 35.1
# # of episode :14280, avg score : 33.9
# # of episode :14300, avg score : 32.4
# # of episode :14320, avg score : 33.2
# # of episode :14340, avg score : 33.2
# # of episode :14360, avg score : 34.2
# # of episode :14380, avg score : 31.6
# # of episode :14400, avg score : 33.9
# # of episode :14420, avg score : 30.0
# # of episode :14440, avg score : 34.5
# # of episode :14460, avg score : 32.4
# # of episode :14480, avg score : 30.1
# # of episode :14500, avg score : 28.9
# # of episode :14520, avg score : 31.1
# # of episode :14540, avg score : 37.0
# # of episode :14560, avg score : 35.1
# # of episode :14580, avg score : 33.0
# # of episode :14600, avg score : 40.3
# # of episode :14620, avg score : 32.5
# # of episode :14640, avg score : 35.1
# # of episode :14660, avg score : 38.1
# # of episode :14680, avg score : 34.6
# # of episode :14700, avg score : 34.0
# # of episode :14720, avg score : 31.7
# # of episode :14740, avg score : 30.5
# # of episode :14760, avg score : 35.2
# # of episode :14780, avg score : 41.2
# # of episode :14800, avg score : 32.5
# # of episode :14820, avg score : 38.5
# # of episode :14840, avg score : 29.2
# # of episode :14860, avg score : 31.5
# # of episode :14880, avg score : 31.6
# # of episode :14900, avg score : 32.5
# # of episode :14920, avg score : 34.5
# # of episode :14940, avg score : 34.4
# # of episode :14960, avg score : 34.5
# # of episode :14980, avg score : 31.6
# # of episode :15000, avg score : 33.6
# # of episode :15020, avg score : 35.5
# # of episode :15040, avg score : 34.2
# # of episode :15060, avg score : 31.1
# # of episode :15080, avg score : 32.5
# # of episode :15100, avg score : 39.8
# # of episode :15120, avg score : 31.6
# # of episode :15140, avg score : 35.0
# # of episode :15160, avg score : 38.0
# # of episode :15180, avg score : 30.6
# # of episode :15200, avg score : 34.0
# # of episode :15220, avg score : 33.2
# # of episode :15240, avg score : 29.3
# # of episode :15260, avg score : 37.8
# # of episode :15280, avg score : 30.4
# # of episode :15300, avg score : 36.0
# # of episode :15320, avg score : 31.6
# # of episode :15340, avg score : 34.6
# # of episode :15360, avg score : 32.8
# # of episode :15380, avg score : 32.9
# # of episode :15400, avg score : 35.7
# # of episode :15420, avg score : 32.4
# # of episode :15440, avg score : 30.1
# # of episode :15460, avg score : 31.6
# # of episode :15480, avg score : 35.1
# # of episode :15500, avg score : 29.7
# # of episode :15520, avg score : 32.1
# # of episode :15540, avg score : 33.6
# # of episode :15560, avg score : 35.1
# # of episode :15580, avg score : 32.4
# # of episode :15600, avg score : 34.0
# # of episode :15620, avg score : 29.9
# # of episode :15640, avg score : 32.4
# # of episode :15660, avg score : 33.6
# # of episode :15680, avg score : 33.4
# # of episode :15700, avg score : 28.2
# # of episode :15720, avg score : 29.9
# # of episode :15740, avg score : 33.0
# # of episode :15760, avg score : 34.1
# # of episode :15780, avg score : 29.4
# # of episode :15800, avg score : 30.9
# # of episode :15820, avg score : 30.2
# # of episode :15840, avg score : 31.9
# # of episode :15860, avg score : 31.2
# # of episode :15880, avg score : 35.0
# # of episode :15900, avg score : 36.2
# # of episode :15920, avg score : 33.8
# # of episode :15940, avg score : 28.6
# # of episode :15960, avg score : 33.8
# # of episode :15980, avg score : 32.5
# # of episode :16000, avg score : 31.6
# # of episode :16020, avg score : 38.4
# # of episode :16040, avg score : 28.6
# # of episode :16060, avg score : 33.8
# # of episode :16080, avg score : 30.9
# # of episode :16100, avg score : 31.4
# # of episode :16120, avg score : 33.7
# # of episode :16140, avg score : 28.1
# # of episode :16160, avg score : 30.9
# # of episode :16180, avg score : 38.2
# # of episode :16200, avg score : 31.8
# # of episode :16220, avg score : 28.9
# # of episode :16240, avg score : 33.5
# # of episode :16260, avg score : 31.2
# # of episode :16280, avg score : 30.9
# # of episode :16300, avg score : 35.6
# # of episode :16320, avg score : 34.6
# # of episode :16340, avg score : 30.6
# # of episode :16360, avg score : 34.1
# # of episode :16380, avg score : 33.5
# # of episode :16400, avg score : 34.7
# # of episode :16420, avg score : 38.8
# # of episode :16440, avg score : 32.1
# # of episode :16460, avg score : 46.4
# # of episode :16480, avg score : 31.1
# # of episode :16500, avg score : 33.0
# # of episode :16520, avg score : 34.5
# # of episode :16540, avg score : 30.1
# # of episode :16560, avg score : 33.5
# # of episode :16580, avg score : 30.1
# # of episode :16600, avg score : 32.5
# # of episode :16620, avg score : 37.1
# # of episode :16640, avg score : 35.4
# # of episode :16660, avg score : 31.6
# # of episode :16680, avg score : 33.9
# # of episode :16700, avg score : 32.4
# # of episode :16720, avg score : 34.5
# # of episode :16740, avg score : 34.1
# # of episode :16760, avg score : 34.2
# # of episode :16780, avg score : 37.7
# # of episode :16800, avg score : 44.6
# # of episode :16820, avg score : 28.4
# # of episode :16840, avg score : 31.3
# # of episode :16860, avg score : 36.0
# # of episode :16880, avg score : 32.5
# # of episode :16900, avg score : 33.5
# # of episode :16920, avg score : 36.1
# # of episode :16940, avg score : 30.9
# # of episode :16960, avg score : 30.7
# # of episode :16980, avg score : 30.8
# # of episode :17000, avg score : 31.1
# # of episode :17020, avg score : 30.9
# # of episode :17040, avg score : 35.6
# # of episode :17060, avg score : 31.1
# # of episode :17080, avg score : 35.8
# # of episode :17100, avg score : 30.9
# # of episode :17120, avg score : 38.0
# # of episode :17140, avg score : 33.9
# # of episode :17160, avg score : 34.4
# # of episode :17180, avg score : 31.9
# # of episode :17200, avg score : 40.9
# # of episode :17220, avg score : 35.5
# # of episode :17240, avg score : 31.9
# # of episode :17260, avg score : 28.9
# # of episode :17280, avg score : 38.0
# # of episode :17300, avg score : 36.0
# # of episode :17320, avg score : 32.9
# # of episode :17340, avg score : 37.5
# # of episode :17360, avg score : 32.4
# # of episode :17380, avg score : 31.6
# # of episode :17400, avg score : 33.4
# # of episode :17420, avg score : 31.2
# # of episode :17440, avg score : 31.8
# # of episode :17460, avg score : 37.4
# # of episode :17480, avg score : 33.0
# # of episode :17500, avg score : 30.6
# # of episode :17520, avg score : 34.9
# # of episode :17540, avg score : 33.0
# # of episode :17560, avg score : 30.9
# # of episode :17580, avg score : 36.0
# # of episode :17600, avg score : 41.2
# # of episode :17620, avg score : 30.6
# # of episode :17640, avg score : 31.1
# # of episode :17660, avg score : 30.2
# # of episode :17680, avg score : 37.4
# # of episode :17700, avg score : 31.4
# # of episode :17720, avg score : 35.1
# # of episode :17740, avg score : 26.6
# # of episode :17760, avg score : 40.1
# # of episode :17780, avg score : 34.9
# # of episode :17800, avg score : 26.6
# # of episode :17820, avg score : 32.9
# # of episode :17840, avg score : 33.0
# # of episode :17860, avg score : 33.0
# # of episode :17880, avg score : 33.6
# # of episode :17900, avg score : 34.7
# # of episode :17920, avg score : 36.6
# # of episode :17940, avg score : 33.0
# # of episode :17960, avg score : 31.3
# # of episode :17980, avg score : 28.4
# # of episode :18000, avg score : 31.6
# # of episode :18020, avg score : 37.3
# # of episode :18040, avg score : 32.1
# # of episode :18060, avg score : 35.2
# # of episode :18080, avg score : 28.9
# # of episode :18100, avg score : 31.1
# # of episode :18120, avg score : 32.8
# # of episode :18140, avg score : 36.5
# # of episode :18160, avg score : 30.2
# # of episode :18180, avg score : 33.4
# # of episode :18200, avg score : 29.8
# # of episode :18220, avg score : 31.0
# # of episode :18240, avg score : 31.6
# # of episode :18260, avg score : 27.9
# # of episode :18280, avg score : 36.6
# # of episode :18300, avg score : 31.6
# # of episode :18320, avg score : 31.7
# # of episode :18340, avg score : 38.2
# # of episode :18360, avg score : 32.3
# # of episode :18380, avg score : 32.1
# # of episode :18400, avg score : 31.9
# # of episode :18420, avg score : 30.8
# # of episode :18440, avg score : 27.9
# # of episode :18460, avg score : 33.1
# # of episode :18480, avg score : 35.9
# # of episode :18500, avg score : 33.4
# # of episode :18520, avg score : 31.6
# # of episode :18540, avg score : 30.3
# # of episode :18560, avg score : 31.4
# # of episode :18580, avg score : 34.0
# # of episode :18600, avg score : 33.9
# # of episode :18620, avg score : 33.3
# # of episode :18640, avg score : 30.6
# # of episode :18660, avg score : 41.3
# # of episode :18680, avg score : 37.9
# # of episode :18700, avg score : 31.6
# # of episode :18720, avg score : 32.8
# # of episode :18740, avg score : 30.2
# # of episode :18760, avg score : 33.0
# # of episode :18780, avg score : 31.1
# # of episode :18800, avg score : 33.0
# # of episode :18820, avg score : 33.0
# # of episode :18840, avg score : 31.2
# # of episode :18860, avg score : 35.7
# # of episode :18880, avg score : 33.7
# # of episode :18900, avg score : 32.9
# # of episode :18920, avg score : 30.7
# # of episode :18940, avg score : 32.4
# # of episode :18960, avg score : 31.4
# # of episode :18980, avg score : 31.8
# # of episode :19000, avg score : 35.5
# # of episode :19020, avg score : 37.4
# # of episode :19040, avg score : 30.6
# # of episode :19060, avg score : 31.4
# # of episode :19080, avg score : 36.6
# # of episode :19100, avg score : 29.5
# # of episode :19120, avg score : 37.6
# # of episode :19140, avg score : 31.2
# # of episode :19160, avg score : 34.5
# # of episode :19180, avg score : 32.5
# # of episode :19200, avg score : 31.5
# # of episode :19220, avg score : 41.0
# # of episode :19240, avg score : 36.6
# # of episode :19260, avg score : 34.0
# # of episode :19280, avg score : 31.4
# # of episode :19300, avg score : 31.6
# # of episode :19320, avg score : 33.5
# # of episode :19340, avg score : 32.6
# # of episode :19360, avg score : 35.8
# # of episode :19380, avg score : 29.7
# # of episode :19400, avg score : 34.1
# # of episode :19420, avg score : 27.9
# # of episode :19440, avg score : 37.8
# # of episode :19460, avg score : 29.2
# # of episode :19480, avg score : 38.1
# # of episode :19500, avg score : 30.8
# # of episode :19520, avg score : 30.6
# # of episode :19540, avg score : 29.6
# # of episode :19560, avg score : 30.9
# # of episode :19580, avg score : 30.6
# # of episode :19600, avg score : 32.2
# # of episode :19620, avg score : 32.4
# # of episode :19640, avg score : 31.6
# # of episode :19660, avg score : 31.4
# # of episode :19680, avg score : 30.4
# # of episode :19700, avg score : 28.1
# # of episode :19720, avg score : 29.2
# # of episode :19740, avg score : 34.0
# # of episode :19760, avg score : 27.4
# # of episode :19780, avg score : 33.5
# # of episode :19800, avg score : 32.5
# # of episode :19820, avg score : 35.0
# # of episode :19840, avg score : 36.6
# # of episode :19860, avg score : 31.4
# # of episode :19880, avg score : 32.5
# # of episode :19900, avg score : 32.2
# # of episode :19920, avg score : 32.0
# # of episode :19940, avg score : 31.2
# # of episode :19960, avg score : 33.5
# # of episode :19980, avg score : 29.6
# # of episode :20000, avg score : 32.5
# # of episode :20020, avg score : 39.6
# # of episode :20040, avg score : 30.1
# # of episode :20060, avg score : 34.6
# # of episode :20080, avg score : 31.6
# # of episode :20100, avg score : 32.4
# # of episode :20120, avg score : 31.8
# # of episode :20140, avg score : 31.6
# # of episode :20160, avg score : 32.5
# # of episode :20180, avg score : 42.6
# # of episode :20200, avg score : 32.1
# # of episode :20220, avg score : 32.7
# # of episode :20240, avg score : 29.8
# # of episode :20260, avg score : 33.8
# # of episode :20280, avg score : 31.6
# # of episode :20300, avg score : 30.4
# # of episode :20320, avg score : 28.6
# # of episode :20340, avg score : 29.6
# # of episode :20360, avg score : 30.0
# # of episode :20380, avg score : 30.7
# # of episode :20400, avg score : 32.3
# # of episode :20420, avg score : 36.0
# # of episode :20440, avg score : 36.6
# # of episode :20460, avg score : 35.8
# # of episode :20480, avg score : 28.2
# # of episode :20500, avg score : 31.7
# # of episode :20520, avg score : 31.4
# # of episode :20540, avg score : 30.6
# # of episode :20560, avg score : 36.1
# # of episode :20580, avg score : 32.8
# # of episode :20600, avg score : 30.6
# # of episode :20620, avg score : 32.9
# # of episode :20640, avg score : 35.6
# # of episode :20660, avg score : 32.5
# # of episode :20680, avg score : 40.9
# # of episode :20700, avg score : 33.8
# # of episode :20720, avg score : 23.9
# # of episode :20740, avg score : 40.9
# # of episode :20760, avg score : 33.0
# # of episode :20780, avg score : 36.4
# # of episode :20800, avg score : 34.2
# # of episode :20820, avg score : 34.9
# # of episode :20840, avg score : 34.7
# # of episode :20860, avg score : 32.1
# # of episode :20880, avg score : 36.2
# # of episode :20900, avg score : 35.4
# # of episode :20920, avg score : 36.6
# # of episode :20940, avg score : 35.6
# # of episode :20960, avg score : 33.6
# # of episode :20980, avg score : 31.0
# # of episode :21000, avg score : 31.6
# # of episode :21020, avg score : 27.5
# # of episode :21040, avg score : 33.8
# # of episode :21060, avg score : 31.8
# # of episode :21080, avg score : 28.0
# # of episode :21100, avg score : 31.6
# # of episode :21120, avg score : 36.2
# # of episode :21140, avg score : 31.4
# # of episode :21160, avg score : 39.0
# # of episode :21180, avg score : 32.6
# # of episode :21200, avg score : 36.0
# # of episode :21220, avg score : 28.3
# # of episode :21240, avg score : 29.4
# # of episode :21260, avg score : 30.4
# # of episode :21280, avg score : 31.4
# # of episode :21300, avg score : 31.4
# # of episode :21320, avg score : 27.6
# # of episode :21340, avg score : 29.3
# # of episode :21360, avg score : 32.8
# # of episode :21380, avg score : 29.9
# # of episode :21400, avg score : 32.4
# # of episode :21420, avg score : 32.9
# # of episode :21440, avg score : 31.2
# # of episode :21460, avg score : 35.6
# # of episode :21480, avg score : 32.2
# # of episode :21500, avg score : 32.4
# # of episode :21520, avg score : 30.9
# # of episode :21540, avg score : 30.1
# # of episode :21560, avg score : 37.5
# # of episode :21580, avg score : 32.4
# # of episode :21600, avg score : 31.8
# # of episode :21620, avg score : 28.9
# # of episode :21640, avg score : 31.1
# # of episode :21660, avg score : 29.6
# # of episode :21680, avg score : 30.1
# # of episode :21700, avg score : 29.2
# # of episode :21720, avg score : 29.6
# # of episode :21740, avg score : 43.4
# # of episode :21760, avg score : 31.1
# # of episode :21780, avg score : 32.0
# # of episode :21800, avg score : 33.4
# # of episode :21820, avg score : 32.1
# # of episode :21840, avg score : 32.0
# # of episode :21860, avg score : 27.4
# # of episode :21880, avg score : 29.5
# # of episode :21900, avg score : 35.7
# # of episode :21920, avg score : 31.6
# # of episode :21940, avg score : 34.9
# # of episode :21960, avg score : 28.4
# # of episode :21980, avg score : 32.4
# # of episode :22000, avg score : 37.9
# # of episode :22020, avg score : 29.1
# # of episode :22040, avg score : 32.4
# # of episode :22060, avg score : 33.2
# # of episode :22080, avg score : 31.2
# # of episode :22100, avg score : 31.7
# # of episode :22120, avg score : 33.5
# # of episode :22140, avg score : 32.0
# # of episode :22160, avg score : 31.3
# # of episode :22180, avg score : 33.0
# # of episode :22200, avg score : 26.5
# # of episode :22220, avg score : 32.8
# # of episode :22240, avg score : 32.8
# # of episode :22260, avg score : 30.4
# # of episode :22280, avg score : 31.9
# # of episode :22300, avg score : 34.5
# # of episode :22320, avg score : 35.3
# # of episode :22340, avg score : 28.2
# # of episode :22360, avg score : 29.6
# # of episode :22380, avg score : 35.2
# # of episode :22400, avg score : 29.1
# # of episode :22420, avg score : 32.0
# # of episode :22440, avg score : 32.4
# # of episode :22460, avg score : 29.1
# # of episode :22480, avg score : 29.6
# # of episode :22500, avg score : 29.4
# # of episode :22520, avg score : 30.9
# # of episode :22540, avg score : 32.6
# # of episode :22560, avg score : 38.9
# # of episode :22580, avg score : 34.1
# # of episode :22600, avg score : 30.1
# # of episode :22620, avg score : 32.1
# # of episode :22640, avg score : 34.1
# # of episode :22660, avg score : 28.4
# # of episode :22680, avg score : 31.4
# # of episode :22700, avg score : 31.6
# # of episode :22720, avg score : 33.4
# # of episode :22740, avg score : 30.9
# # of episode :22760, avg score : 29.9
# # of episode :22780, avg score : 35.5
# # of episode :22800, avg score : 30.1
# # of episode :22820, avg score : 29.9
# # of episode :22840, avg score : 33.4
# # of episode :22860, avg score : 32.2
# # of episode :22880, avg score : 34.7
# # of episode :22900, avg score : 33.8
# # of episode :22920, avg score : 31.2
# # of episode :22940, avg score : 42.0
# # of episode :22960, avg score : 32.2
# # of episode :22980, avg score : 35.6
# # of episode :23000, avg score : 32.8
# # of episode :23020, avg score : 33.8
# # of episode :23040, avg score : 34.3
# # of episode :23060, avg score : 31.0
# # of episode :23080, avg score : 30.8
# # of episode :23100, avg score : 32.2
# # of episode :23120, avg score : 29.6
# # of episode :23140, avg score : 29.9
# # of episode :23160, avg score : 35.7
# # of episode :23180, avg score : 27.9
# # of episode :23200, avg score : 31.1
# # of episode :23220, avg score : 35.3
# # of episode :23240, avg score : 30.9
# # of episode :23260, avg score : 39.0
# # of episode :23280, avg score : 38.2
# # of episode :23300, avg score : 33.9
# # of episode :23320, avg score : 31.6
# # of episode :23340, avg score : 35.1
# # of episode :23360, avg score : 32.8
# # of episode :23380, avg score : 32.1
# # of episode :23400, avg score : 31.4
# # of episode :23420, avg score : 31.1
# # of episode :23440, avg score : 33.9
# # of episode :23460, avg score : 32.4
# # of episode :23480, avg score : 27.8
# # of episode :23500, avg score : 31.3
# # of episode :23520, avg score : 34.5
# # of episode :23540, avg score : 31.6
# # of episode :23560, avg score : 33.3
# # of episode :23580, avg score : 27.5
# # of episode :23600, avg score : 32.8
# # of episode :23620, avg score : 31.7
# # of episode :23640, avg score : 29.2
# # of episode :23660, avg score : 34.2
# # of episode :23680, avg score : 33.5
# # of episode :23700, avg score : 33.4
# # of episode :23720, avg score : 28.8
# # of episode :23740, avg score : 31.5
# # of episode :23760, avg score : 34.9
# # of episode :23780, avg score : 30.4
# # of episode :23800, avg score : 30.8
# # of episode :23820, avg score : 32.4
# # of episode :23840, avg score : 30.9
# # of episode :23860, avg score : 30.1
# # of episode :23880, avg score : 47.0
# # of episode :23900, avg score : 37.9
# # of episode :23920, avg score : 37.1
# # of episode :23940, avg score : 44.0
# # of episode :23960, avg score : 28.8
# # of episode :23980, avg score : 31.0
# # of episode :24000, avg score : 31.2
# # of episode :24020, avg score : 34.9
# # of episode :24040, avg score : 32.4
# # of episode :24060, avg score : 39.9
# # of episode :24080, avg score : 33.8
# # of episode :24100, avg score : 29.6
# # of episode :24120, avg score : 28.6
# # of episode :24140, avg score : 29.1
# # of episode :24160, avg score : 27.2
# # of episode :24180, avg score : 40.6
# # of episode :24200, avg score : 33.6
# # of episode :24220, avg score : 38.1
# # of episode :24240, avg score : 32.4
# # of episode :24260, avg score : 33.0
# # of episode :24280, avg score : 31.3
# # of episode :24300, avg score : 29.3
# # of episode :24320, avg score : 34.0
# # of episode :24340, avg score : 30.1
# # of episode :24360, avg score : 33.0
# # of episode :24380, avg score : 30.2
# # of episode :24400, avg score : 34.6
# # of episode :24420, avg score : 29.3
# # of episode :24440, avg score : 36.4
# # of episode :24460, avg score : 34.2
# # of episode :24480, avg score : 27.8
# # of episode :24500, avg score : 31.2
# # of episode :24520, avg score : 31.4
# # of episode :24540, avg score : 34.0
# # of episode :24560, avg score : 32.2
# # of episode :24580, avg score : 32.5
# # of episode :24600, avg score : 32.0
# # of episode :24620, avg score : 32.2
# # of episode :24640, avg score : 28.8
# # of episode :24660, avg score : 32.1
# # of episode :24680, avg score : 34.1
# # of episode :24700, avg score : 29.6
# # of episode :24720, avg score : 32.8
# # of episode :24740, avg score : 31.5
# # of episode :24760, avg score : 33.6
# # of episode :24780, avg score : 29.8
# # of episode :24800, avg score : 31.6
# # of episode :24820, avg score : 30.5
# # of episode :24840, avg score : 31.4
# # of episode :24860, avg score : 34.0
# # of episode :24880, avg score : 31.9
# # of episode :24900, avg score : 30.1
# # of episode :24920, avg score : 30.6
# # of episode :24940, avg score : 27.9
# # of episode :24960, avg score : 32.5
# # of episode :24980, avg score : 31.2
# # of episode :25000, avg score : 31.6
# # of episode :25020, avg score : 33.7
# # of episode :25040, avg score : 32.3
# # of episode :25060, avg score : 30.1
# # of episode :25080, avg score : 32.0
# # of episode :25100, avg score : 35.6
# # of episode :25120, avg score : 32.0
# # of episode :25140, avg score : 34.5
# # of episode :25160, avg score : 31.3
# # of episode :25180, avg score : 33.4
# # of episode :25200, avg score : 33.8
# # of episode :25220, avg score : 30.4
# # of episode :25240, avg score : 30.8
# # of episode :25260, avg score : 29.6
# # of episode :25280, avg score : 39.3
# # of episode :25300, avg score : 31.3
# # of episode :25320, avg score : 31.1
# # of episode :25340, avg score : 32.2
# # of episode :25360, avg score : 31.4
# # of episode :25380, avg score : 30.9
# # of episode :25400, avg score : 33.3
# # of episode :25420, avg score : 33.1
# # of episode :25440, avg score : 28.1
# # of episode :25460, avg score : 37.7
# # of episode :25480, avg score : 36.0
# # of episode :25500, avg score : 33.5
# # of episode :25520, avg score : 35.6
# # of episode :25540, avg score : 32.6
# ...
# # of episode :91580, avg score : 20.6
# # of episode :91600, avg score : 19.1
# # of episode :91620, avg score : 19.1
# # of episode :91640, avg score : 20.5
# # of episode :91660, avg score : 19.6
# # of episode :91680, avg score : 23.3
# # of episode :91700, avg score : 18.2
# # of episode :91720, avg score : 18.2
# # of episode :91740, avg score : 21.2
# # of episode :91760, avg score : 20.5
# # of episode :91780, avg score : 18.4
# # of episode :91800, avg score : 20.1
# # of episode :91820, avg score : 18.8
# # of episode :91840, avg score : 19.6
# # of episode :91860, avg score : 18.7
# # of episode :91880, avg score : 18.8
# # of episode :91900, avg score : 20.9
# # of episode :91920, avg score : 22.3
# # of episode :91940, avg score : 19.3
# # of episode :91960, avg score : 19.2
# # of episode :91980, avg score : 21.7
# # of episode :92000, avg score : 19.9
# # of episode :92020, avg score : 21.6
# # of episode :92040, avg score : 18.8
# # of episode :92060, avg score : 19.8
# # of episode :92080, avg score : 21.8
# # of episode :92100, avg score : 18.9
# # of episode :92120, avg score : 19.4
# # of episode :92140, avg score : 18.1
# # of episode :92160, avg score : 22.2
# # of episode :92180, avg score : 19.2
# # of episode :92200, avg score : 18.6
# # of episode :92220, avg score : 20.4
# # of episode :92240, avg score : 21.4
# # of episode :92260, avg score : 18.0
# # of episode :92280, avg score : 20.6
# # of episode :92300, avg score : 18.4
# # of episode :92320, avg score : 20.9
# # of episode :92340, avg score : 18.9
# # of episode :92360, avg score : 20.6
# # of episode :92380, avg score : 20.4
# # of episode :92400, avg score : 19.6
# # of episode :92420, avg score : 19.2
# # of episode :92440, avg score : 19.0
# # of episode :92460, avg score : 21.8
# # of episode :92480, avg score : 19.5
# # of episode :92500, avg score : 20.1
# # of episode :92520, avg score : 21.4
# # of episode :92540, avg score : 19.6
# # of episode :92560, avg score : 18.6
# # of episode :92580, avg score : 20.4
# # of episode :92600, avg score : 19.6
# # of episode :92620, avg score : 20.9
# # of episode :92640, avg score : 18.2
# # of episode :92660, avg score : 20.8
# # of episode :92680, avg score : 19.9
# # of episode :92700, avg score : 18.9
# # of episode :92720, avg score : 20.1
# # of episode :92740, avg score : 19.0
# # of episode :92760, avg score : 19.9
# # of episode :92780, avg score : 20.4
# # of episode :92800, avg score : 20.1
# # of episode :92820, avg score : 19.7
# # of episode :92840, avg score : 21.4
# # of episode :92860, avg score : 19.9
# # of episode :92880, avg score : 20.1
# # of episode :92900, avg score : 18.6
# # of episode :92920, avg score : 20.1
# # of episode :92940, avg score : 18.5
# # of episode :92960, avg score : 19.1
# # of episode :92980, avg score : 20.4
# # of episode :93000, avg score : 18.3
# # of episode :93020, avg score : 20.4
# # of episode :93040, avg score : 19.2
# # of episode :93060, avg score : 20.4
# # of episode :93080, avg score : 20.3
# # of episode :93100, avg score : 20.6
# # of episode :93120, avg score : 21.1
# # of episode :93140, avg score : 20.6
# # of episode :93160, avg score : 19.2
# # of episode :93180, avg score : 21.4
# # of episode :93200, avg score : 19.1
# # of episode :93220, avg score : 19.9
# # of episode :93240, avg score : 19.9
# # of episode :93260, avg score : 20.6
# # of episode :93280, avg score : 18.6
# # of episode :93300, avg score : 20.8
# # of episode :93320, avg score : 19.9
# # of episode :93340, avg score : 19.4
# # of episode :93360, avg score : 19.1
# # of episode :93380, avg score : 17.9
# # of episode :93400, avg score : 20.2
# # of episode :93420, avg score : 18.8
# # of episode :93440, avg score : 20.4
# # of episode :93460, avg score : 18.6
# # of episode :93480, avg score : 20.9
# # of episode :93500, avg score : 20.4
# # of episode :93520, avg score : 19.9
# # of episode :93540, avg score : 19.1
# # of episode :93560, avg score : 20.8
# # of episode :93580, avg score : 18.8
# # of episode :93600, avg score : 20.7
# # of episode :93620, avg score : 19.9
# # of episode :93640, avg score : 20.5
# # of episode :93660, avg score : 19.8
# # of episode :93680, avg score : 21.4
# # of episode :93700, avg score : 20.1
# # of episode :93720, avg score : 21.7
# # of episode :93740, avg score : 19.6
# # of episode :93760, avg score : 19.7
# # of episode :93780, avg score : 19.8
# # of episode :93800, avg score : 21.1
# # of episode :93820, avg score : 20.4
# # of episode :93840, avg score : 19.6
# # of episode :93860, avg score : 19.5
# # of episode :93880, avg score : 18.6
# # of episode :93900, avg score : 20.7
# # of episode :93920, avg score : 32.1
# # of episode :93940, avg score : 37.3
# # of episode :93960, avg score : 21.0
# # of episode :93980, avg score : 21.6
# # of episode :94000, avg score : 20.2
# # of episode :94020, avg score : 20.2
# # of episode :94040, avg score : 20.4
# # of episode :94060, avg score : 19.6
# # of episode :94080, avg score : 21.1
# # of episode :94100, avg score : 20.2
# # of episode :94120, avg score : 20.0
# # of episode :94140, avg score : 21.8
# # of episode :94160, avg score : 18.9
# # of episode :94180, avg score : 19.1
# # of episode :94200, avg score : 20.7
# # of episode :94220, avg score : 19.1
# # of episode :94240, avg score : 19.8
# # of episode :94260, avg score : 20.8
# # of episode :94280, avg score : 19.8
# # of episode :94300, avg score : 18.2
# # of episode :94320, avg score : 18.6
# # of episode :94340, avg score : 20.4
# # of episode :94360, avg score : 17.6
# # of episode :94380, avg score : 21.2
# # of episode :94400, avg score : 22.3
# # of episode :94420, avg score : 26.9
# # of episode :94440, avg score : 19.2
# # of episode :94460, avg score : 20.4
# # of episode :94480, avg score : 20.4
# # of episode :94500, avg score : 20.1
# # of episode :94520, avg score : 18.4
# # of episode :94540, avg score : 20.2
# # of episode :94560, avg score : 19.1
# # of episode :94580, avg score : 18.0
# # of episode :94600, avg score : 19.4
# # of episode :94620, avg score : 17.4
# # of episode :94640, avg score : 19.9
# # of episode :94660, avg score : 18.3
# # of episode :94680, avg score : 20.1
# # of episode :94700, avg score : 20.6
# # of episode :94720, avg score : 21.4
# # of episode :94740, avg score : 18.9
# # of episode :94760, avg score : 19.4
# # of episode :94780, avg score : 19.1
# # of episode :94800, avg score : 18.2
# # of episode :94820, avg score : 19.1
# # of episode :94840, avg score : 19.0
# # of episode :94860, avg score : 20.9
# # of episode :94880, avg score : 19.6
# # of episode :94900, avg score : 20.4
# # of episode :94920, avg score : 20.1
# # of episode :94940, avg score : 20.7
# # of episode :94960, avg score : 17.9
# # of episode :94980, avg score : 19.1
# # of episode :95000, avg score : 19.3
# # of episode :95020, avg score : 18.6
# # of episode :95040, avg score : 22.2
# # of episode :95060, avg score : 18.6
# # of episode :95080, avg score : 20.4
# # of episode :95100, avg score : 19.8
# # of episode :95120, avg score : 20.0
# # of episode :95140, avg score : 18.8
# # of episode :95160, avg score : 18.3
# # of episode :95180, avg score : 19.8
# # of episode :95200, avg score : 19.6
# # of episode :95220, avg score : 21.2
# # of episode :95240, avg score : 18.9
# # of episode :95260, avg score : 18.9
# # of episode :95280, avg score : 21.2
# # of episode :95300, avg score : 20.1
# # of episode :95320, avg score : 18.8
# # of episode :95340, avg score : 19.2
# # of episode :95360, avg score : 18.3
# # of episode :95380, avg score : 21.6
# # of episode :95400, avg score : 20.1
# # of episode :95420, avg score : 19.1
# # of episode :95440, avg score : 21.2
# # of episode :95460, avg score : 19.1
# # of episode :95480, avg score : 18.1
# # of episode :95500, avg score : 19.6
# # of episode :95520, avg score : 19.2
# # of episode :95540, avg score : 20.4
# # of episode :95560, avg score : 19.8
# # of episode :95580, avg score : 18.4
# # of episode :95600, avg score : 20.0
# # of episode :95620, avg score : 22.8
# # of episode :95640, avg score : 20.0
# # of episode :95660, avg score : 21.8
# # of episode :95680, avg score : 21.3
# # of episode :95700, avg score : 18.4
# # of episode :95720, avg score : 19.4
# # of episode :95740, avg score : 21.4
# # of episode :95760, avg score : 20.4
# # of episode :95780, avg score : 18.7
# # of episode :95800, avg score : 18.9
# # of episode :95820, avg score : 19.1
# # of episode :95840, avg score : 18.5
# # of episode :95860, avg score : 17.5
# # of episode :95880, avg score : 19.4
# # of episode :95900, avg score : 21.0
# # of episode :95920, avg score : 21.1
# # of episode :95940, avg score : 19.9
# # of episode :95960, avg score : 19.9
# # of episode :95980, avg score : 21.6
# # of episode :96000, avg score : 20.9
# # of episode :96020, avg score : 19.4
# # of episode :96040, avg score : 19.9
# # of episode :96060, avg score : 19.1
# # of episode :96080, avg score : 19.6
# # of episode :96100, avg score : 21.1
# # of episode :96120, avg score : 20.2
# # of episode :96140, avg score : 19.6
# # of episode :96160, avg score : 19.8
# # of episode :96180, avg score : 20.4
# # of episode :96200, avg score : 19.0
# # of episode :96220, avg score : 18.9
# # of episode :96240, avg score : 19.7
# # of episode :96260, avg score : 20.9
# # of episode :96280, avg score : 17.0
# # of episode :96300, avg score : 18.9
# # of episode :96320, avg score : 20.1
# # of episode :96340, avg score : 20.2
# # of episode :96360, avg score : 21.1
# # of episode :96380, avg score : 18.9
# # of episode :96400, avg score : 19.4
# # of episode :96420, avg score : 21.2
# # of episode :96440, avg score : 19.5
# # of episode :96460, avg score : 20.2
# # of episode :96480, avg score : 19.5
# # of episode :96500, avg score : 18.9
# # of episode :96520, avg score : 18.1
# # of episode :96540, avg score : 18.9
# # of episode :96560, avg score : 19.6
# # of episode :96580, avg score : 20.1
# # of episode :96600, avg score : 21.1
# # of episode :96620, avg score : 22.2
# # of episode :96640, avg score : 19.5
# # of episode :96660, avg score : 34.6
# # of episode :96680, avg score : 18.7
# # of episode :96700, avg score : 21.1
# # of episode :96720, avg score : 20.7
# # of episode :96740, avg score : 19.9
# # of episode :96760, avg score : 17.9
# # of episode :96780, avg score : 19.5
# # of episode :96800, avg score : 19.2
# # of episode :96820, avg score : 18.8
# # of episode :96840, avg score : 20.2
# # of episode :96860, avg score : 19.8
# # of episode :96880, avg score : 18.4
# # of episode :96900, avg score : 17.6
# # of episode :96920, avg score : 19.3
# # of episode :96940, avg score : 19.6
# # of episode :96960, avg score : 18.8
# # of episode :96980, avg score : 19.8
# # of episode :97000, avg score : 21.6
# # of episode :97020, avg score : 17.6
# # of episode :97040, avg score : 19.6
# # of episode :97060, avg score : 20.1
# # of episode :97080, avg score : 19.9
# # of episode :97100, avg score : 19.6
# # of episode :97120, avg score : 20.1
# # of episode :97140, avg score : 20.2
# # of episode :97160, avg score : 18.9
# # of episode :97180, avg score : 20.0
# # of episode :97200, avg score : 18.2
# # of episode :97220, avg score : 18.6
# # of episode :97240, avg score : 20.4
# # of episode :97260, avg score : 18.9
# # of episode :97280, avg score : 20.6
# # of episode :97300, avg score : 19.3
# # of episode :97320, avg score : 19.4
# # of episode :97340, avg score : 20.5
# # of episode :97360, avg score : 21.0
# # of episode :97380, avg score : 18.9
# # of episode :97400, avg score : 18.8
# # of episode :97420, avg score : 19.3
# # of episode :97440, avg score : 19.6
# # of episode :97460, avg score : 19.8
# # of episode :97480, avg score : 20.8
# # of episode :97500, avg score : 18.8
# # of episode :97520, avg score : 19.1
# # of episode :97540, avg score : 20.8
# # of episode :97560, avg score : 19.6
# # of episode :97580, avg score : 19.4
# # of episode :97600, avg score : 18.4
# # of episode :97620, avg score : 19.5
# # of episode :97640, avg score : 18.2
# # of episode :97660, avg score : 19.8
# # of episode :97680, avg score : 19.5
# # of episode :97700, avg score : 24.4
# # of episode :97720, avg score : 21.1
# # of episode :97740, avg score : 40.5
# # of episode :97760, avg score : 29.4
# # of episode :97780, avg score : 19.2
# # of episode :97800, avg score : 17.8
# # of episode :97820, avg score : 24.6
# # of episode :97840, avg score : 20.4
# # of episode :97860, avg score : 21.3
# # of episode :97880, avg score : 24.4
# # of episode :97900, avg score : 21.4
# # of episode :97920, avg score : 21.0
# # of episode :97940, avg score : 23.8
# # of episode :97960, avg score : 19.3
# # of episode :97980, avg score : 22.1
# # of episode :98000, avg score : 22.4
# # of episode :98020, avg score : 21.9
# # of episode :98040, avg score : 20.9
# # of episode :98060, avg score : 20.9
# # of episode :98080, avg score : 20.2
# # of episode :98100, avg score : 20.8
# # of episode :98120, avg score : 20.5
# # of episode :98140, avg score : 20.0
# # of episode :98160, avg score : 20.8
# # of episode :98180, avg score : 19.6
# # of episode :98200, avg score : 18.6
# # of episode :98220, avg score : 20.2
# # of episode :98240, avg score : 19.1
# # of episode :98260, avg score : 21.2
# # of episode :98280, avg score : 18.9
# # of episode :98300, avg score : 18.9
# # of episode :98320, avg score : 18.1
# # of episode :98340, avg score : 20.1
# # of episode :98360, avg score : 20.1
# # of episode :98380, avg score : 20.1
# # of episode :98400, avg score : 18.6
# # of episode :98420, avg score : 19.6
# # of episode :98440, avg score : 19.8
# # of episode :98460, avg score : 22.5
# # of episode :98480, avg score : 19.4
# # of episode :98500, avg score : 18.1
# # of episode :98520, avg score : 21.1
# # of episode :98540, avg score : 17.9
# # of episode :98560, avg score : 20.0
# # of episode :98580, avg score : 19.9
# # of episode :98600, avg score : 19.1
# # of episode :98620, avg score : 18.1
# # of episode :98640, avg score : 19.6
# # of episode :98660, avg score : 19.8
# # of episode :98680, avg score : 20.5
# # of episode :98700, avg score : 19.4
# # of episode :98720, avg score : 20.1
# # of episode :98740, avg score : 18.6
# # of episode :98760, avg score : 20.0
# # of episode :98780, avg score : 18.1
# # of episode :98800, avg score : 19.2
# # of episode :98820, avg score : 18.1
# # of episode :98840, avg score : 21.4
# # of episode :98860, avg score : 21.2
# # of episode :98880, avg score : 17.5
# # of episode :98900, avg score : 20.1
# # of episode :98920, avg score : 19.5
# # of episode :98940, avg score : 19.9
# # of episode :98960, avg score : 18.1
# # of episode :98980, avg score : 18.8
# # of episode :99000, avg score : 21.5
# # of episode :99020, avg score : 20.9
# # of episode :99040, avg score : 20.6
# # of episode :99060, avg score : 19.1
# # of episode :99080, avg score : 18.9
# # of episode :99100, avg score : 20.2
# # of episode :99120, avg score : 20.2
# # of episode :99140, avg score : 19.9
# # of episode :99160, avg score : 21.6
# # of episode :99180, avg score : 18.6
# # of episode :99200, avg score : 19.4
# # of episode :99220, avg score : 20.4
# # of episode :99240, avg score : 20.6
# # of episode :99260, avg score : 20.9
# # of episode :99280, avg score : 20.8
# # of episode :99300, avg score : 19.1
# # of episode :99320, avg score : 20.0
# # of episode :99340, avg score : 20.9
# # of episode :99360, avg score : 19.9
# # of episode :99380, avg score : 20.0
# # of episode :99400, avg score : 19.9
# # of episode :99420, avg score : 19.6
# # of episode :99440, avg score : 20.4
# # of episode :99460, avg score : 20.3
# # of episode :99480, avg score : 19.6
# # of episode :99500, avg score : 20.3
# # of episode :99520, avg score : 19.4
# # of episode :99540, avg score : 19.9
# # of episode :99560, avg score : 18.1
# # of episode :99580, avg score : 17.7
# # of episode :99600, avg score : 19.5
# # of episode :99620, avg score : 18.6
# # of episode :99640, avg score : 18.9
# # of episode :99660, avg score : 21.6
# # of episode :99680, avg score : 20.2
# # of episode :99700, avg score : 17.6
# # of episode :99720, avg score : 18.6
# # of episode :99740, avg score : 19.1
# # of episode :99760, avg score : 19.5
# # of episode :99780, avg score : 20.4
# # of episode :99800, avg score : 19.6
# # of episode :99820, avg score : 18.8
# # of episode :99840, avg score : 19.4
# # of episode :99860, avg score : 19.8
# # of episode :99880, avg score : 17.9
# # of episode :99900, avg score : 19.1
# # of episode :99920, avg score : 19.1
# # of episode :99940, avg score : 20.4
# # of episode :99960, avg score : 25.1
# # of episode :99980, avg score : 19.8

# %%
torch.save(model.state_dict(), './model_weights/recurrent_model_'+str(100000))
