# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 3
T_horizon     = 20
class Agent(nn.Module):
    def __init__(self, state_dim,action_dim,learning_rate,env_num):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.env_num = env_num
        
        super(Agent,self).__init__()
        self.memory = [[] for _ in range(self.env_num)]
        
        
        self.fc1 = nn.Linear(self.state_dim,256)
        self.policy = nn.Linear(256, self.action_dim)
        self.value = nn.Linear(256, 1)
        self.optimizer = optim.Adam(self.parameters(),lr = learning_rate)
        
    def get_action(self,x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.policy(x)
        prob = F.softmax(x, dim = softmax_dim)
        return prob
    
    def get_value(self,x):
        x = F.relu(self.fc1(x))
        x = self.value(x)
        return x
    
    def put_data(self,i,data):
        self.memory[i].append(data)
        
    def make_batch(self,i):
        state_list, action_list, reward_list, next_state_list, prob_list, done_list = [],[],[],[],[],[]
        for data in self.memory[i]:
            state,action,reward,next_state,prob,done = data
            state_list.append(state)
            action_list.append([action])
            reward_list.append([reward])
            prob_list.append([prob])
            next_state_list.append(next_state)
            done_mask = 0 if done else 1
            done_list.append([done_mask])
        
        
        s,a,r,next_s,done_mask,prob = torch.tensor(state_list,dtype=torch.float),\
                                        torch.tensor(action_list),torch.tensor(reward_list),\
                                        torch.tensor(next_state_list,dtype=torch.float),\
                                        torch.tensor(done_list,dtype = torch.float),\
                                        torch.tensor(prob_list)
        return s,a,r,next_s,done_mask,prob
    
    def train(self):
        for i in range(K_epoch):
            stop = 0
            for env in range(self.env_num):
                state,action,reward, next_state,done_mask,action_prob = self.make_batch(env)
                #print('state.shape : ',state.shape)
                #print('state.shape[0] : ',state.shape[0])
                if state.shape[0] == 0 :
                    stop += 1
                    continue
                td_error = reward + gamma * self.get_value(next_state) * done_mask
                delta = td_error - self.get_value(state)
                delta = delta.detach().numpy()
                advantage_list = []
                advantage = 0.0
                for delta_t in delta[::-1]:
                    advantage = gamma * lmbda * advantage + delta_t[0]
                    advantage_list.append([advantage])
                advantage_list.reverse()
                if env == stop:
                    all_advantage = torch.tensor(advantage_list,dtype = torch.float)
                    all_action = action
                    all_state = state
                    all_action_prob = action_prob
                    all_td_error = td_error
                else :
                    all_advantage = torch.cat((all_advantage,torch.tensor(advantage_list,dtype= torch.float)))
                    all_action = torch.cat((all_action,action))
                    all_state = torch.cat((all_state,state))
                    all_action_prob = torch.cat((all_action_prob,action_prob))
                    all_td_error = torch.cat((all_td_error,td_error))
            #print('all_state : ',all_state.shape)
            now_action = self.get_action(all_state,softmax_dim = 1)
            now_action = now_action.gather(1,all_action)
            
            ratio = torch.exp(torch.log(now_action) - torch.log(all_action_prob))
            
            surr1 = ratio * all_advantage
            surr2 = torch.clamp(ratio , 1-eps_clip, 1 + eps_clip) * all_advantage
            loss = - torch.min(surr1,surr2) + F.smooth_l1_loss(self.get_value(all_state),all_td_error.detach())
            
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()
        self.memory = [[] for _ in range(self.env_num)]

# %%
import numpy as np
import os
from Building import Building
#from Agent import Agent
import time
#====================================================================================


#====================================================================================
#Building Setting
lift_num = 1
buliding_height = 5
max_people_in_floor = 8
max_people_in_elevator = 10

add_people_at_step = 25
add_people_prob = 0.8

#Create building with 4 elevators, height 10, max people 30 in each floor

env_num = 4

#building = Building(lift_num, buliding_height, max_people_in_floor,max_people_in_elevator)

#Agent controls each elevator
#agent = Agent(buliding_height, lift_num, 4)
#agent.reload(280)
#The goal is to bring down all the people in the building to the ground floor

epochs = 1000
max_steps = 100
global_step = 0
T_horizon = 20
reward_list = []
print_interval = 20

def finish_checker(x):
    return x[:-2]

# %%
model = Agent((buliding_height)+ max_people_in_elevator + (lift_num *2),4,learning_rate,env_num)
print_interval = 20
ave_reward = 0

# %%
building_list = [Building(lift_num, buliding_height, max_people_in_floor,max_people_in_elevator) for _ in range(env_num)]

# %%
epochs = 10001
print_interval = 20

# %%
for epoch in range(epochs):
    [building.empty_building() for building in building_list]
    [building.generate_people(add_people_prob) for building in building_list]
    state_list = [building.get_state() for building in building_list]
    
    done_list = [False for _ in range(env_num)]
    global_step = 0
    while not all(done_list):
        #print('global_step : ', global_step,done_list)
        for t in range(T_horizon):
            #print('global_step : ',global_step,' done_list : ',done_list)
            global_step += 1
            if (global_step % 25 == 0) & global_step > 0 :
                #building.generate_people(add_people_prob/2)
                pass
            action_prob_list = [model.get_action(torch.from_numpy(np.array(state)).float()) for state in state_list]
            m_list = [Categorical(action_prob) for action_prob in action_prob_list]
            action_list = [m.sample().item() for m in m_list]
            [building.perform_action([action_list[idx]]) for idx,building in enumerate(building_list)]
            reward_list = [building.get_reward() for building in building_list]
            
            next_state_list = [building.get_state() for building in building_list]
            finished_list = [next_state.copy() for next_state in next_state_list]
            finished_list = list(map(finish_checker, finished_list))
            for i in range(env_num):
                if (sum(finished_list[i]) == 0.0) : #and (done_list[i] != True):
                    reward_list[i] = 100. #* building.target
                    done_list[i] = True
            #print(sum(finished))
            #print('global_step : ',global_step,'state : ',state, 'action : ', action, 'reward : ',reward/float(first_state), 'done : ',done)
            #print('global_step : ',global_step,'state : ',state, 'action : ', action, 'reward : ',reward/10., 'done : ',done)
            #model.put_data((state, action, reward/float(first_state), next_state, action_prob[action].item(), done))
            for i in range(env_num):
                #if reward_list[i] == 0 and done_list[i] == True:
                #    continue
                model.put_data(i,(state_list[i], action_list[i], reward_list[i]/100.0,\
                                next_state_list[i], action_prob_list[i][action_list[i]].item(), done_list[i]))
            state_list = next_state_list
            for i in range(env_num):
                if (global_step > 300):
                    done_list[i] = True
            if all(done_list) == True:
                break
        model.train()
    ave_reward += global_step 
    #print("Epoch: %d Step: %d Average Reward: %.4f"%(epoch, global_step, ave_reward/global_step))
    if epoch%print_interval==0 and epoch!=0:
        print("# of episode :{}, avg score : {:.1f}".format(epoch, ave_reward/print_interval))
        ave_reward = 0
    if (epoch % 100 == 0 )& (epoch != 0):
        torch.save(model.state_dict(), './model_weights/vari_env_model_'+str(epoch))
    reward_list.append(global_step)
# Out:
# # of episode :20, avg score : 241.7
# # of episode :40, avg score : 162.1
# # of episode :60, avg score : 130.4
# # of episode :80, avg score : 122.4
# # of episode :100, avg score : 103.8
# # of episode :120, avg score : 105.7
# # of episode :140, avg score : 93.3
# # of episode :160, avg score : 90.8
# # of episode :180, avg score : 76.8
# # of episode :200, avg score : 95.4
# # of episode :220, avg score : 90.8
# # of episode :240, avg score : 89.7
# # of episode :260, avg score : 78.6
# # of episode :280, avg score : 77.6
# # of episode :300, avg score : 73.1
# # of episode :320, avg score : 64.8
# # of episode :340, avg score : 71.5
# # of episode :360, avg score : 61.0
# # of episode :380, avg score : 67.8
# # of episode :400, avg score : 71.6
# # of episode :420, avg score : 70.5
# # of episode :440, avg score : 67.6
# # of episode :460, avg score : 74.1
# # of episode :480, avg score : 71.1
# # of episode :500, avg score : 77.9
# # of episode :520, avg score : 59.5
# # of episode :540, avg score : 69.4
# # of episode :560, avg score : 65.7
# # of episode :580, avg score : 65.7
# # of episode :600, avg score : 65.5
# # of episode :620, avg score : 63.4
# # of episode :640, avg score : 66.1
# # of episode :660, avg score : 62.2
# # of episode :680, avg score : 57.9
# # of episode :700, avg score : 59.3
# # of episode :720, avg score : 58.7
# # of episode :740, avg score : 67.5
# # of episode :760, avg score : 54.5
# # of episode :780, avg score : 65.2
# # of episode :800, avg score : 59.4
# # of episode :820, avg score : 60.6
# # of episode :840, avg score : 56.6
# # of episode :860, avg score : 52.7
# # of episode :880, avg score : 63.2
# # of episode :900, avg score : 63.0
# # of episode :920, avg score : 60.1
# # of episode :940, avg score : 51.8
# # of episode :960, avg score : 48.9
# # of episode :980, avg score : 58.0
# # of episode :1000, avg score : 56.9
# # of episode :1020, avg score : 57.8
# # of episode :1040, avg score : 65.1
# # of episode :1060, avg score : 52.0
# # of episode :1080, avg score : 54.7
# # of episode :1100, avg score : 53.9
# # of episode :1120, avg score : 66.0
# # of episode :1140, avg score : 61.6
# # of episode :1160, avg score : 50.0
# # of episode :1180, avg score : 52.0
# # of episode :1200, avg score : 69.4
# # of episode :1220, avg score : 58.7
# # of episode :1240, avg score : 58.1
# # of episode :1260, avg score : 47.4
# # of episode :1280, avg score : 60.6
# # of episode :1300, avg score : 54.1
# # of episode :1320, avg score : 57.6
# # of episode :1340, avg score : 45.5
# # of episode :1360, avg score : 49.0
# # of episode :1380, avg score : 51.9
# # of episode :1400, avg score : 54.4
# # of episode :1420, avg score : 53.6
# # of episode :1440, avg score : 52.1
# # of episode :1460, avg score : 59.6
# # of episode :1480, avg score : 48.3
# # of episode :1500, avg score : 50.0
# # of episode :1520, avg score : 56.5
# # of episode :1540, avg score : 45.0
# # of episode :1560, avg score : 50.6
# # of episode :1580, avg score : 55.1
# # of episode :1600, avg score : 57.4
# # of episode :1620, avg score : 50.0
# # of episode :1640, avg score : 46.1
# # of episode :1660, avg score : 44.6
# # of episode :1680, avg score : 55.2
# # of episode :1700, avg score : 51.5
# # of episode :1720, avg score : 54.3
# # of episode :1740, avg score : 47.9
# # of episode :1760, avg score : 45.1
# # of episode :1780, avg score : 49.0
# # of episode :1800, avg score : 50.5
# # of episode :1820, avg score : 46.1
# # of episode :1840, avg score : 49.9
# # of episode :1860, avg score : 48.8
# # of episode :1880, avg score : 45.6
# # of episode :1900, avg score : 43.9
# # of episode :1920, avg score : 59.9
# # of episode :1940, avg score : 45.0
# # of episode :1960, avg score : 52.1
# # of episode :1980, avg score : 47.5
# # of episode :2000, avg score : 45.2
# # of episode :2020, avg score : 42.6
# # of episode :2040, avg score : 47.0
# # of episode :2060, avg score : 48.1
# # of episode :2080, avg score : 47.0
# # of episode :2100, avg score : 46.0
# # of episode :2120, avg score : 44.6
# # of episode :2140, avg score : 46.6
# # of episode :2160, avg score : 50.5
# # of episode :2180, avg score : 48.0
# # of episode :2200, avg score : 38.9
# # of episode :2220, avg score : 43.7
# # of episode :2240, avg score : 44.1
# # of episode :2260, avg score : 44.3
# # of episode :2280, avg score : 41.0
# # of episode :2300, avg score : 40.2
# # of episode :2320, avg score : 36.8
# # of episode :2340, avg score : 41.4
# # of episode :2360, avg score : 38.2
# # of episode :2380, avg score : 49.0
# # of episode :2400, avg score : 44.9
# # of episode :2420, avg score : 37.9
# # of episode :2440, avg score : 39.8
# # of episode :2460, avg score : 45.1
# # of episode :2480, avg score : 41.6
# # of episode :2500, avg score : 39.2
# # of episode :2520, avg score : 40.1
# # of episode :2540, avg score : 41.4
# # of episode :2560, avg score : 43.5
# # of episode :2580, avg score : 39.5
# # of episode :2600, avg score : 37.0
# # of episode :2620, avg score : 40.4
# # of episode :2640, avg score : 45.0
# # of episode :2660, avg score : 42.4
# # of episode :2680, avg score : 37.0
# # of episode :2700, avg score : 38.4
# # of episode :2720, avg score : 36.5
# # of episode :2740, avg score : 36.6
# # of episode :2760, avg score : 35.7
# # of episode :2780, avg score : 43.9
# # of episode :2800, avg score : 39.2
# # of episode :2820, avg score : 36.4
# # of episode :2840, avg score : 37.1
# # of episode :2860, avg score : 39.1
# # of episode :2880, avg score : 39.5
# # of episode :2900, avg score : 35.6
# # of episode :2920, avg score : 36.0
# # of episode :2940, avg score : 37.8
# # of episode :2960, avg score : 39.5
# # of episode :2980, avg score : 45.3
# # of episode :3000, avg score : 35.6
# # of episode :3020, avg score : 39.7
# # of episode :3040, avg score : 37.2
# # of episode :3060, avg score : 36.9
# # of episode :3080, avg score : 38.2
# # of episode :3100, avg score : 35.5
# # of episode :3120, avg score : 37.2
# # of episode :3140, avg score : 36.4
# # of episode :3160, avg score : 35.2
# # of episode :3180, avg score : 35.2
# # of episode :3200, avg score : 36.6
# # of episode :3220, avg score : 34.9
# # of episode :3240, avg score : 35.6
# # of episode :3260, avg score : 38.1
# # of episode :3280, avg score : 35.0
# # of episode :3300, avg score : 36.2
# # of episode :3320, avg score : 34.3
# # of episode :3340, avg score : 37.7
# # of episode :3360, avg score : 33.5
# # of episode :3380, avg score : 37.1
# # of episode :3400, avg score : 34.6
# # of episode :3420, avg score : 34.6
# # of episode :3440, avg score : 35.8
# # of episode :3460, avg score : 35.8
# # of episode :3480, avg score : 34.0
# # of episode :3500, avg score : 32.5
# # of episode :3520, avg score : 37.1
# # of episode :3540, avg score : 36.0
# # of episode :3560, avg score : 36.6
# # of episode :3580, avg score : 39.3
# # of episode :3600, avg score : 35.4
# # of episode :3620, avg score : 33.3
# # of episode :3640, avg score : 33.8
# # of episode :3660, avg score : 32.8
# # of episode :3680, avg score : 31.9
# # of episode :3700, avg score : 35.2
# # of episode :3720, avg score : 35.6
# # of episode :3740, avg score : 36.1
# # of episode :3760, avg score : 37.3
# # of episode :3780, avg score : 33.0
# # of episode :3800, avg score : 32.5
# # of episode :3820, avg score : 33.4
# # of episode :3840, avg score : 33.6
# # of episode :3860, avg score : 36.3
# # of episode :3880, avg score : 33.6
# # of episode :3900, avg score : 31.9
# # of episode :3920, avg score : 30.9
# # of episode :3940, avg score : 34.5
# # of episode :3960, avg score : 35.2
# # of episode :3980, avg score : 33.4
# # of episode :4000, avg score : 35.7
# # of episode :4020, avg score : 34.1
# # of episode :4040, avg score : 32.7
# # of episode :4060, avg score : 35.0
# # of episode :4080, avg score : 36.7
# # of episode :4100, avg score : 31.6
# # of episode :4120, avg score : 34.7
# # of episode :4140, avg score : 31.1
# # of episode :4160, avg score : 32.9
# # of episode :4180, avg score : 31.9
# # of episode :4200, avg score : 34.9
# # of episode :4220, avg score : 31.5
# # of episode :4240, avg score : 30.4
# # of episode :4260, avg score : 33.5
# # of episode :4280, avg score : 31.7

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
lmbda         = 0.95
eps_clip      = 0.1
K_epoch       = 3
T_horizon     = 20
class Agent(nn.Module):
    def __init__(self, state_dim,action_dim,learning_rate):
        self.state_dim = state_dim
        self.action_dim = action_dim
        
        super(Agent,self).__init__()
        self.memory = []

        self.fc1 = nn.Linear(self.state_dim,256)
        self.policy = nn.Linear(256, self.action_dim)
        self.value = nn.Linear(256, 1)
        self.optimizer = optim.Adam(self.parameters(),lr = learning_rate)
        
    def get_action(self,x, softmax_dim = 0):
        x = F.relu(self.fc1(x))
        x = self.policy(x)
        prob = F.softmax(x, dim = softmax_dim)
        return prob
    
    def get_value(self,x):
        x = F.relu(self.fc1(x))
        x = self.value(x)
        return x
    
    def put_data(self,data):
        self.memory.append(data)
        
    def make_batch(self):
        state_list, action_list, reward_list, next_state_list, prob_list, done_list = [],[],[],[],[],[]
        for data in self.memory:
            state,action,reward,next_state,prob,done = data
            state_list.append(state)
            action_list.append([action])
            reward_list.append([reward])
            prob_list.append([prob])
            next_state_list.append(next_state)
            done_mask = 0 if done else 1
            done_list.append([done_mask])
        self.memory = []
        
        s,a,r,next_s,done_mask,prob = torch.tensor(state_list,dtype=torch.float),\
                                        torch.tensor(action_list),torch.tensor(reward_list),\
                                        torch.tensor(next_state_list,dtype=torch.float),\
                                        torch.tensor(done_list,dtype = torch.float),\
                                        torch.tensor(prob_list)
        return s,a,r,next_s,done_mask,prob
    
    def train(self):
        state,action,reward, next_state,done_mask,action_prob = self.make_batch()
        
        for i in range(K_epoch):
            td_error = reward + gamma * self.get_value(next_state) * done_mask
            delta = td_error - self.get_value(state)
            delta = delta.detach().numpy()
            advantage_list = []
            advantage = 0.0
            for delta_t in delta[::-1]:
                advantage = gamma * lmbda * advantage + delta_t[0]
                advantage_list.append([advantage])
            advantage_list.reverse()
            advantage = torch.tensor(advantage_list,dtype = torch.float)
            
            
            now_action = self.get_action(state,softmax_dim = 1)
            now_action = now_action.gather(1,action)
            
            ratio = torch.exp(torch.log(now_action) - torch.log(action_prob))
            
            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio , 1-eps_clip, 1 + eps_clip) * advantage
            loss = - torch.min(surr1,surr2) + F.smooth_l1_loss(self.get_value(state),td_error.detach())
            
            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

import numpy as np
import os
from Building import Building
#from Agent import Agent
import time
#====================================================================================


#====================================================================================
#Building Setting
lift_num = 1
buliding_height = 5
max_people_in_floor = 8
max_people_in_elevator = 10

add_people_at_step = 25
add_people_prob = 0.8

#Create building with 4 elevators, height 10, max people 30 in each floor
building = Building(lift_num, buliding_height, max_people_in_floor,max_people_in_elevator)

epochs = 1000
max_steps = 100
global_step = 0
T_horizon = 20
reward_list = []
print_interval = 20

model = Agent((buliding_height)+ max_people_in_elevator + (lift_num *2),4,learning_rate)
#model.load_state_dict(torch.load('./model_weights/model_3500'))
print_interval = 20
ave_reward = 0 




for epoch in range(epochs):
    building.empty_building()
    while building.target == 0 :
        building.generate_people(add_people_prob)
    state = building.get_state()
    done = False
    global_step = 0
    while not done:
        for t in range(T_horizon):
            global_step += 1
            if (global_step % 25 == 0) & global_step > 0 :
                #building.generate_people(add_people_prob/2)
                pass
            action_prob = model.get_action(torch.from_numpy(np.array(state)).float())
            m = Categorical(action_prob)
            action = m.sample().item()
            building.perform_action([action])
            reward = building.get_reward() 
            
            next_state = building.get_state()
            building.print_building(global_step)
            print(action)            
            time.sleep(1)
            finished = next_state.copy()
            del finished[-2]
            if (sum(finished) == 0.0) :
                reward = 100
                done = True
            model.put_data((state, action, reward/10.0, next_state, action_prob[action].item(), done))
            state = next_state
            
            if done or global_step > 300:
                done = True
                break

        model.train()
    ave_reward += global_step 
    #print("Epoch: %d Step: %d Average Reward: %.4f"%(epoch, global_step, ave_reward/global_step))
    if epoch%print_interval==0 and epoch!=0:
        print("# of episode :{}, avg score : {:.1f}".format(epoch, ave_reward/print_interval))
        ave_reward = 0
    if (epoch % 100 == 0 )& (epoch != 0):
        torch.save(model.state_dict(), './model_weights/model_'+str(epoch))
    reward_list.append(global_step)
